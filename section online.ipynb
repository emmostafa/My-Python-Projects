# %%
#برنامج يعد عدد الكلمات وحصر عدد مرات التكرار لكل كلمه فى القاموس
dic={}
x=input('enter the text')
words=x.split()
for word in words:
    if word in dic:
        dic[word]+=1
    else:
        dic[word]=1
print(dic)
# Out:
# {'eman': 1, 'love': 1, 'python': 1}

# %%
#اليوزر يدخل نص والبرنامج يشيل كل الحروف المكرره 
text= input ('enter your text')
x=''
for i in text:
    if i not in x:
        x+=i
print(x)
# Out:
# eman

# %%
#قايمه بها مجموعه ارقام الكود يطلع تانى اكبر عدد فى القايمه
l1=[1,3,4,5,6,78,33,22]
maxnum=l1[0]
secnum=l1[0]
for i in l1:
    if i >maxnum:
        secnum=maxnum
        maxnum=i
print(maxnum)
print(secnum)
# Out:
# 78
# 6

# %%
#اليوزر هيدخل نص عايز النص يتطبع بطريقه معكوسه
text= input()
word=text.split()
x=len(word)-1
while x >0:
    print(word[x],end=' ')
    x-=1

# %%
text=input("enter a string")
word=text.split()
reversed_word=words[::-1]
print(reversed_word)
print(" ".join(reversed_word))
# Out:
# ['python', 'love', 'eman']
# python love eman

# %%
#قايمه بها مجموعه كلمات عايزه اضع الا ليها نفس الحجم فى قايمه 
names =['eman','osama','eslam','sama']
group={}
for word in names:
    l=len(word)
    if l not in group:
        group[l]=[]
    group[l].append(word)
for l,word in group.items():
    print(f'حروف {l}كلمات من :{word}')
print(group)
# Out:
# حروف 4كلمات من :['eman', 'sama']
# حروف 5كلمات من :['osama', 'eslam']
# {4: ['eman', 'sama'], 5: ['osama', 'eslam']}

# %%
import math 
ope=input("enter the operation")
num1=int(input())
num2=int(input())
try:
    if ope=="+":
        print(num1+num2)
    elif ope=="-":
        print(num1-num2)
    elif ope=="*":
        print(num1*num2)
    elif ope=="/":
        print(num1/num2)
except ValueError:
    print("ادخل رقم صحيح")

# %%
grades=[]
for i in range(5):
    grade=float(input())
    grades.append(grade)
maxi=max(grades)
mini=min(grades)
aver=sum(grades)/len(grades)
print(grades)
print(maxi,mini)

# %%
#عايزين قايمه فيه مصفوفات 2D عايزين مجموعهم
mat = [[2,8],
       [9,1],
       [10,6]]
sum =0 
for i in mat :
    for j in i :
        sum +=j 
print (sum)
# Out:
# 36

# %%
#هندخل نص وعايززن نقص جزء معين منه
text=input("enter a text")
start=int(input("enter a start index"))
end=int(input("enter a end index"))
print(text[start:end])
print(text[::start],text[end::])
# Out:
# nmo
# ensf stafa

# %%
#  يدخل رقم موبايل يقولي في الاول نيتوورك نمبر وبعدين يطبع باقي الرقم من غير التلت ارقام 
# نيتورك نمبر هو رقم الشركه
num=input("enter a number")
print(f'network{num[:3]}')
print(num[4:])
# Out:
# network012
# 8005481

# %%
#factorail
num1=int(input("enter a number"))
fact=1
for i in range(1,num1+1):
    fact*=i #fact(old)*i=fact(new)
print(fact)
print('-'*20)
#factorail of function
def factorial(n):
    if n==1:
        return 1
    else:
        return n * factorial(n-1)
print(factor(5))
# Out:
# 120
# --------------------
# 120

# %%
#اليوزر يدخل ايميل والبرنامج يطلع اليوزر نيم منه
email = input ('enter u email :') # ahmed22@gmail.com
c = 0
for i in email :
    if i != '@' :
        c +=1 
    else : 
        break
print (c)
print (email[:c])

# %%
email = input ('enter u email :') # ahmed22@gmail.com
v = email.index('@')
print (email.index('@'))
print (email[:v])

# %%
email_address = input("Enter your email address: ")
username = email_address.split('@')[0]
print("Your username is:", username)
# Out:
# Your username is: eman3344

# %%
#Write a program that:
#Stores items and prices using a dictionary and Uses a loop to let the user: Add items,Stop when finished,Calculates total cost
dic={'apple':200,'egg':100,'banana':300}
total=0
while True:
    key=input()
    if key=='excit':
        break
    if key in dic:
        price=dic[key]
        total+=price
    else:
        print('هذا المنتج مش موجود')
print(f'المجموع الكلى {total}')
# Out:
# المجموع الكلى 600

# %% [markdown]
# رايت الفايل ويرجع يقرا اللى كتبخ فى الملف

# %%
with open ('file.txt','w')as f:
    f.write ('hello eman\n sammma\n monaaa')
with open ('file.txt','r')as f:
    text=f.readlines()
    x= [i.strip() for i in text]
print(text)
print(x)
print(len(x))
# Out:
# ['hello eman\n', ' sammma\n', ' monaaa']
# ['hello eman', 'sammma', 'monaaa']
# 3

# %% [markdown]
# نطبع اكبر كلمه موجوده فى الفايل

# %%
c=''
for word in x:
    if len(word) >len(c):
        c=word
print(c)
# Out:
# hello eman

# %% [markdown]
# المضرووب بالدوال

# %%
num=int(input())
def fact(x):
    c=1
    for i in range(1,x+1):
        c*=i
    print(c)
fact(num)
# Out:
# 6

# %% [markdown]
# داله تعد عدد الكلمات فى الفايل

# %%
def count(x):
    with open (x,'r') as f:
        contact= f . read()
        words = contact. split()
        print(words)
        return len (words)
    print(words)
a = 'f.txt'
result=count(a)
print(result)
# Out:
# ['hello', 'eman', 'sammma', 'monaaa']
# 4

# %% [markdown]
# داله اليوزر يدخل اسم الشبكه والباس يشوفه صح ولا فى فايل
