# %%
n=5
for i in range (n):
    for j in range(n):
        print('*',end='')
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
n=5
for i in range (n):
    for j in range(n):
        print('*',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n):
    for j in range(i,n):
        print('*',end='')
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(n):
    for j in range(i,n):
        print('',end='')
    for j in range(i+1):
        print('*',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n):
    
    
    for j in range(i,n):
        print('',end='')
    for j in range(i):
        print('*',end='')
    for j in range(i+1):
        print('*',end='')
    print()
# Out:
# *
# ***
# *****
# *******
# *********

# %%
#حساب كام عدد الحروف المشتركه بينهم 
sentence=input("enter asentence:")
vowels="a e i o A E T O U"
count=0
for char in sentence:
    if char in vowels:
        count+=1
print("number of vowels:", count)
# Out:
# number of vowels: 3

# %%
num=int(input("enter a number:"))
for i in range(1,13):
    print(num,"x" ,i,"=",num*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60

# %%
for i in range (1,100+1):
    if i %3==0:
        print("fizz")
    elif i %5==0:
        print("Buzz")
    elif i % 3==0 and i %5==0:
        print("fizzBuzz")
    else:
        print(i)
# Out:
# 1
# 2
# fizz
# 4
# Buzz
# fizz
# 7
# 8
# fizz
# Buzz
# 11
# fizz
# 13
# 14
# fizz
# 16
# 17
# fizz
# 19
# Buzz
# fizz
# 22
# 23
# fizz
# Buzz
# 26
# fizz
# 28
# 29
# fizz
# 31
# 32
# fizz
# 34
# Buzz
# fizz
# 37
# 38
# fizz
# Buzz
# 41
# fizz
# 43
# 44
# fizz
# 46
# 47
# fizz
# 49
# Buzz
# fizz
# 52
# 53
# fizz
# Buzz
# 56
# fizz
# 58
# 59
# fizz
# 61
# 62
# fizz
# 64
# Buzz
# fizz
# 67
# 68
# fizz
# Buzz
# 71
# fizz
# 73
# 74
# fizz
# 76
# 77
# fizz
# 79
# Buzz
# fizz
# 82
# 83
# fizz
# Buzz
# 86
# fizz
# 88
# 89
# fizz
# 91
# 92
# fizz
# 94
# Buzz
# fizz
# 97
# 98
# fizz
# Buzz

# %%
student=[]
n=int(input("How many students?"))
name=input("entur student name")
percent=input("enter percent")
student.append({"name":name,"percent":percent})
print("\student results:")
# Out:
# \student results:

# %%
n=int(input("enter size:"))
for i in range(n):
    print("*" *n)
# Out:
# ****
# ****
# ****
# ****

# %%
x=float(input("ادخل طول الضلع الاول"))
y=float(input("ادخل طول الضلع التانى"))
z=float(input("ادخل طول الضلع التالت"))
if x==y==z :
    print("المثلث متساوى الاضلاع")
elif x==y or x==z or z==y:
    print("المثلث متساوى الساقين")
else:
    print("المثلث مختلف الاضلاع")
# Out:
# المثلث متساوى الاضلاع

# %%
with open("msg.txt","w")as f:
   f.write("Hello python\n")
print("تم انشاء الملف وكتابه الرساله")
# Out:
# تم انشاء الملف وكتابه الرساله

# %%
num=int(input("enter a number:"))
if num%2==0:
    print(f"{num} num is even")
else:
    print(f"{num} is odd")
# Out:
# 8 num is even

# %%
num=int(input("enter a number:"))
square=num**2
print(f"the square is the num is {num}:{square}")
# Out:
# the square is the num is 4:16

# %%
matrix=[[12,23,45],[33,6,7],[6,10,55]]
sum=0
minimum= matrix[0][0]
maximum= matrix[0][0]
for row in range(len(matrix)):
    for column in range(len(matrix[row])):
        sum+=matrix[row][column]
        if matrix[row][column]<minimum:
            minimum=matrix[row][column]
        if matrix [row][column]>maximum:
            maximum=matrix[row][column]
print(minimum)
print(maximum)
print(sum)

sum_of_rows=[]
for row in range(len(matrix)):
    sum_of_row=0
    for column in range(len(matrix[row])):
        sum_of_row+=matrix[row][column]
        sum_of_rows.append(sum_of_row)
print(sum_of_rows)


sum_of_columns=[]
for colum in range (len(matrix)):
    sum_of_column=0
    for row in range(len(matrix)):
        sum_of_columns.append(sum_of_column)
print(sum_of_columns)
for r in range(len(matrix)):
    for c in range(len(matrix[r])):
        if r==c:
            sum+=matrix[r][c]
print(sum)


sec_diagonal_sum=0
n=len(matrix)
for r in range(n):
    for c in range(len(matrix[r])):
        if(r+c)==(n-1):
          sec_diagonal_sum+=matrix[r][c]
           print(f"Adding number at [{r}][{c}]{matrix[r][c]}")
    print("secondary diagonal sum:",sec_diagonal_sum)
# Out:
#   Cell In[22], line 44
#     print(f"Adding number at [{r}][{c}]{matrix[r][c]}")
#     ^
# IndentationError: unexpected indent
