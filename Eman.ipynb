# %%
try:
   with open("eman.txt","w") as f:
        f.write("Hello\n eman")
except FileNotFoundError:
    print("الملف غير موجود")

# %%
try:
    with open ("eman.txt","r")as f:
        print(f.read())
except FileNotFoundError:
    print("الملف غير موجود")
# Out:
# Hello
#  eman
