# %%
nums=[3,8,2,6]
i=nums[0]+nums[2]
j=[i % 2]
print(j)
# Out:
# [1]

# %%
def parabola():
    print("حساب القطع المكافى معادالته (y-l)=a(x-k)**2")
    #ندخل المعاملات a,l,k
    a =float(input("enter value 'a"))
    k=float(input("enter value 'k"))
    l=float(input("enter value 'l"))
    if a ==0:
        print("not parabola")
    return
   #حساب المسافه من البوره للدليل 
    c= 1 / (4 * a)
   #احداثيات راس القطع
    vertex_x = k 
    vertex_y = l
   #احداثيات البوره
    focus_x= K
    focus_y=l -c
   #معادله الدليل
    y=l-a
    print(f"تم حساب خصاىص القطع المكافى:y={a}(x-{k})**2+{l}")
    print(f"الراس:({vertex_x},{vertex_y})")
    print(f"معادله الدليل :y={y}")
parabola()
# Out:
# حساب القطع المكافى معادالته (y-l)=a(x-k)**2

# %%
import math
def ellips():
    print("شكل القطع الناقص")
    print("معادله القطع الناقص هى :(x-h)**2/a**2+(y-k)**2/b**2")
    h=float(input("enter value h"))
    k=float(input("enter value k"))
    a=float(input("enter value a"))
    b=float(input("enter value b"))
    #شروط القطع الناقص a,bموجبيين and a>b
    if a<b :
        print("خطا لازم a>b")  
        return
    if a<0 or b<0:
        print("خطا لازم a,b موجبين")
        return
    #حساب البعد المركزى
    c_squared=a**2-b**2
    c=math.sqrt(c_squared)
    #الاختلاف المركزى
    e=c/a
    #المركز
    center=(h,k)
    #الراس
    vertex_1=(h+a,k)
    vertex_2=(h-a,k)
    #البوره
    focus_1=(h+c,k)
    focus_2=(h-c,k)
    #طول المحور الاكبر 
    major_length=2*a
    #طول المحور الاصغر
    minar_length=2*b
    print("معلومات القطع الناقص")
    print(f"center is :({center[0]},{center[1]})")
    print(f"نصف المحور الاكبر:{a}")
    print(f"نصف المحور الاصغر:{b}")
    print(f"المسافه البوريه c:{c}")
    print("-"*40)
    print(f"طول المحور الاكبر :{major_length}")
    print(f"طول المحور الاصغر:{minar_length}")
    print(f"الاختلاف المركزى e:{e}")
ellips()
# Out:
# شكل القطع الناقص
# معادله القطع الناقص هى :(x-h)**2/a**2+(y-k)**2/b**2
# معلومات القطع الناقص
# center is :(3.0,4.0)
# نصف المحور الاكبر:16.0
# نصف المحور الاصغر:9.0
# المسافه البوريه c:13.228756555322953
# ----------------------------------------
# طول المحور الاكبر :32.0
# طول المحور الاصغر:18.0
# الاختلاف المركزى e:0.8267972847076845

# %%
#ادخال مجموعه ارقام او اسامى اى حاجه وتفصل بينهم بفصله وحطهم فى قايمه
string_value=input("ادخال القيم او المنتجات (apple,Eman,English)")
items_list=string_value.split(',')
print("القايمه هى" ,items_list)
